# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ((x <= 9) -> (x^2 <= A>)) = (x > 9) or (x^2 <= A)
#
# (y^2 > A) or (y <= 9)
#
#
# -----
#
# ((x > 9) or (x^2 <= A)) and ((y^2 > A) or (y <= 9))
#
# 1. (x > 9) or (x <= sqrt(A)) => A >= 81
# 2. y > sqrt(A) or (y <= 9)  => A < 100
#
# Ответ 99

# %%
def f(x,y,A):
    return ((x <= 9) <= (x * x <= A)) and  ((y * y <= A) <= (y <= 9))

for A in range(300):
    ans = 1
    for x in range(300):
        for y in range(300):
            ans &= f(x, y, A)
    if ans: print(A)
# Out:
# 81
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $\neg(x \not \in A) \lor \neg (x \in P) \lor (x \in Q)$
#
#
# $(x \in A) \lor (x \not \in P) \lor (x \in Q)$
#
# $(x \in A) \lor (x > 62) \lor (x < 12) \lor ( 52 \leq x \leq 92)$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $(- \infty, 12) \cup [52, +\infty)$

# %% [markdown]
# Нужно покрыть полуинтервал $[12, 52) $
# $A = [10, X] \to A = [10, 52]$
#
# Ответ: 52

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ (x \not \in B) \lor (x \in A) \lor (x \not \in C)$$
# $$ (x < 10) \lor (x > 23) \lor (x < 12)  \lor (x > 30) \lor (x \in A)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $A$ должен покрывать $[12, 23]$ меньше нельзя $ A = [12, 23] \to len(A) = 23 - 12 = 11$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $A = (x \in A)$
#
# $ P \to ((Q \land \neg A) \to \neg P)$
#
# $ P \to ( \neg (Q \lor \neg A) \lor \neg P)$
#
# $ P \to ((\neg Q \lor A) \lor \neg P)$
#
# $\neg P \lor ((\neg Q \lor A) \lor \neg P)$
#
# $(\neg P) \lor (\neg Q \lor A) \lor (\neg P)$
#
# $(\neg P) \lor (\neg Q) \lor (A)$
#
# $\neg P = (- \infty, 20) \cup (67, +\infty)$
#
# $\neg Q = (- \infty, 33) \cup (98, +\infty)$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
