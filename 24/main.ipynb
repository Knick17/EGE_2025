# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f = open('24.txt', 'r')

min_G = 10e10
lines = f.readlines()

for line in lines:
    if line.count('G') <= min_G: min_G = line.count('G')

d = dict()

for line in lines:
    if line.count('G') == min_G:
        print(line)
        
        for word in line: d[word] = line.count(word)
        break

mx = max(d.values())
max([elem for elem in d.keys() if d[elem] == mx])
# Out:
# ...
# 'T'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f = open('24_1.txt', 'r')

s = f.readline().split('XZZY')

max([len(elem) for elem in s]) + 6 # ИЛИ +3 ЕСЛИ САМАЯ ПЕРВАЯ, ПОСЛЕДНЯЯ ПОПАЛАСЬ

# xzzy askdkasdoada xzzy => zzy askdkasdoada xzz
# askdkasdoada XZZY => askdkasdoada XZZ
# Out:
# 1713
