# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 5 = 101
# 1 = 001
# 4 = 100


# АДРЕС СЕТИ = адрес_узла & Маска сети
#mask = 255.255.248.0

#204.16.168.0 = 255.255.248.0 & адрес_узла

for i in range(256):
    for j in range(256):
        for k in range(256):
            if 0 == l & 0 and k & 248 == 168 and 16 == 255 & j and 204 == 255 & i:
                print(i, j,k,'_', sep='.')
                print('\n')
# Out:
# 204.16.168._
#
#
# 204.16.169._
#
#
# 204.16.170._
#
#
# 204.16.171._
#
#
# 204.16.172._
#
#
# 204.16.173._
#
#
# 204.16.174._
#
#
# 204.16.175._
